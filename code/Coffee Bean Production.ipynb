# %%
import os

try:
    os.chdir('/Users/cha/Desktop/공모전/삼성화재X포스텍_리스크경진대회/내코드/data/')
    print("Directory changed")
except OSError:
    print("Can't change the Current Working Directory")
# Out:
# Directory changed

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import datetime
from datetime import timedelta

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import platform
if platform.system() == 'Darwin': 
        plt.rc('font', family='AppleGothic') 
elif platform.system() == 'Windows': 
        plt.rc('font', family='Malgun Gothic') 
elif platform.system() == 'Linux': 
        plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
os.getcwd()
# Out:
# '/Users/cha/Desktop/공모전/삼성화재X포스텍_리스크경진대회/내코드/data'

# %% [markdown]
# # Data Load

# %%
arabica = pd.read_excel('원두별생산량/arabica.xlsx')
robusta = pd.read_excel('원두별생산량/robusta.xlsx')

# %%
bean = arabica.copy()

# %%
bean['Robusta coffee production'] = robusta['Robusta coffee production']

# %%
bean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 3 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       18 non-null     int64
#  1   Arabica coffee production  18 non-null     int64
#  2   Robusta coffee production  18 non-null     int64
# dtypes: int64(3)
# memory usage: 560.0 bytes

# %% [markdown]
# # Visualization

# %%
bean['Year'] = pd.to_datetime(bean['Year'], format='%Y')

# %%
fig, ax1 = plt.subplots(figsize=(25, 10))

line1 = ax1.plot(bean['Year'], bean['Arabica coffee production'], label='Arabica Price', color='r')
line2 = ax1.plot(bean['Year'], bean['Robusta coffee production'], label='Robusta Price', color='b')

lines = line1 + line2
labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, fontsize = 18, loc='upper right')
ax1.set_ylabel('1,000 60 kilogram bags', fontdict={'fontsize':15})

# plt.xticks(range(len(a))[::len(a)//300], a.index[::len(a)//300].strftime('%Y-%m'))
# plt.xticks(A.index[::200], A.index[::200].strftime('%Y-%m-%d'), rotation=45)
plt.title('Coffee Bean Production', fontdict = {'fontsize' : 30})
plt.rcParams['font.size'] = 15
plt.show()

# %%
bean.set_index('Year', inplace=True)

# %%
range(len(bean))[::len(bean)//9]
# Out:
# range(0, 18, 2)

# %%
fig, ax1 = plt.subplots(figsize=(20, 7))

line1 = ax1.plot(bean['Year'], bean['Arabica coffee production'], label='아라비카 원두 생산량')

lines = line1
labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, fontsize = 18, loc='upper right')
ax1.set_ylabel('1,000 60 kg', fontdict={'fontsize':15})

#plt.xticks(range(len(bean))[::len(bean)//9], bean['Year'][::len(bean)//9].dt.strftime('%Y'))
# plt.xticks(A.index[::200], A.index[::200].strftime('%Y-%m-%d'), rotation=45)
plt.title('아라비카 원두 생산량', fontdict = {'fontsize' : 20})
plt.rcParams['font.size'] = 15
plt.show()

# %%
plt.figure(figsize=(20, 8))
sns.barplot(x='Year', y='Arabica coffee production', data=bean)
plt.xticks(rotation=90)
plt.xlabel('Year')
plt.ylabel('Total')
plt.title('Arabica Coffee Bean Production')
plt.show()

# %% [markdown]
# # 2016~

# %%
z = bean[bean['Year'].dt.year>=2016]

# %%
fig, ax1 = plt.subplots(figsize=(20, 7))

line1 = ax1.plot(z['Year'], z['Arabica coffee production'], label='아라비카 원두 생산량')
# ax1.plot([datetime.date(2017,1,1),datetime.date(2021,1,1)], [95224, 87404],color="red", linewidth=1)
# ax1.plot([datetime.date(2018,1,1),datetime.date(2022,1,1)], [104976, 95004],color="red", linewidth=1)

lines = line1
labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, fontsize = 18, loc='upper right')
ax1.set_ylabel('1,000 60 kg', fontdict={'fontsize':15})

# plt.xticks(range(len(a))[::len(a)//300], a.index[::len(a)//300].strftime('%Y-%m'))
# plt.xticks(A.index[::200], A.index[::200].strftime('%Y-%m-%d'), rotation=45)
plt.title('아라비카 원두 생산량 2016~2022', fontdict = {'fontsize' : 20})
plt.rcParams['font.size'] = 15
plt.show()

# %%
z
# Out:
#          Year  Arabica coffee production
# 11 2016-01-01                     101036
# 12 2017-01-01                      95224
# 13 2018-01-01                     104976
# 14 2019-01-01                      94946
# 15 2020-01-01                     102077
# 16 2021-01-01                      87404
# 17 2022-01-01                      95004
